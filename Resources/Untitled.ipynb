# %%
import pandas as pd

# %%
df = pd.read_csv("cities.csv")

# %%
df
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    wenceslau braz -23.87  -49.80     82.00        75          23
# 1           ushuaia -54.80  -68.30     42.80        60          75
# 2         piacabucu -10.41  -36.43     82.80        59          15
# 3          freeport  40.66  -73.58     64.99        93          90
# 4     leningradskiy  69.38  178.42     31.28        91          82
# ..              ...    ...     ...       ...       ...         ...
# 564        cururupu  -1.83  -44.87     87.40        58         100
# 565         birjand  32.87   59.22     60.80         5           0
# 566          pravia  43.49   -6.15     62.60        77          40
# 567      baruun-urt  46.68  113.28     26.89        92          86
# 568         cozumel  20.51  -86.95     84.20        83          75
#
#      Wind Speed Country        Date
# 0          3.00      BR  2020-10-20
# 1         23.04      AR  2020-10-20
# 2         13.15      BR  2020-10-20
# ...

# %%
print(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>wenceslau braz</td>
#       <td>-23.87</td>
#       <td>-49.80</td>
#       <td>82.00</td>
#       <td>75</td>
#       <td>23</td>
#       <td>3.00</td>
#       <td>BR</td>
#       <td>2020-10-20</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ushuaia</td>
#       <td>-54.80</td>
#       <td>-68.30</td>
#       <td>42.80</td>
#       <td>60</td>
#       <td>75</td>
#       <td>23.04</td>
#       <td>AR</td>
#       <td>2020-10-20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>piacabucu</td>
#       <td>-10.41</td>
#       <td>-36.43</td>
#       <td>82.80</td>
# ...
